# %% [markdown]
# # Weather report forecasting Analysis & Graphical Speculation on Dashboard ( EXPLORATORY DATA ANALYSIS )

# %%
import pandas as pd

# %%
#Loading CSV file
data=pd.read_excel("weather_dataset_stage1.xls")
#showing initial 10 records
data.head(10)
# Out:
#      weather_dataset Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3921     2022-07-20'     '70.1'     '35.0'     '37.4'     '29.6'      '4.9'
# 3922     2022-07-21'     '65.3'     '60.0'     '49.8'     '29.6'      '3.7'
# 3923     2022-07-22'     '65.4'     '52.0'     '42.7'     '29.6'      '4.2'
# 3924     2022-07-23'     '67.1'     '48.0'     '45.2'     '29.6'      '5.3'
# 3925     2022-07-24'     '64.1'     '62.0'     '49.8'     '29.6'      '3.6'
# 3926     2022-07-25'     '62.8'     '60.0'     '48.1'     '29.7'      '2.5'
# 3927     2022-07-26'     '60.6'     '68.0'     '48.9'     '29.8'      '1.7'
# 3928     2022-07-27'     '61.7'     '64.0'     '47.4'     '29.9'      '2.2'
# 3929     2022-07-28'     '60.5'     '61.0'     '45.3'     '29.7'      '4.0'
# 3930     2022-07-28'     '60.5'     '61.0'     '45.3'     '29.7'      '4.0'
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 3921      '8.0'    '293.0'     '0.12'     '4.26'  ...      '74.0'       '9.0'
# 3922      '6.3'     '38.0'     '0.12'     '4.26'  ...      '88.0'      '31.0'
# 3923      '6.7'    '230.0'     '0.12'     '4.26'  ...      '93.0'      '14.0'
# 3924      '8.6'    '228.0'     '0.23'     '4.37'  ...      '87.0'      '26.0'
# 3925      '5.8'    '240.0'     '0.24'     '4.38'  ...      '86.0'      '35.0'
# 3926      '4.0'    '242.0'     '0.33'     '4.47'  ...      '90.0'      '36.0'
# 3927      '2.9'    '357.0'     '0.33'     '4.47'  ...      '90.0'      '40.0'
# 3928      '4.0'     '66.0'     '0.33'     '4.47'  ...      '96.0'      '35.0'
# 3929      '6.2'    '248.0'     '0.35'     '4.49'  ...      '94.0'      '35.0'
# 3930      '6.2'    '248.0'     '0.35'     '4.49'  ...      '94.0'      '35.0'
#
#      Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 3921     '29.65'    '29.505'      '17.3'      '27.6'      '82.3'
# 3922     '29.71'    '29.568'      '13.8'      '19.6'      '79.5'
# 3923    '29.707'    '29.583'      '16.1'      '25.3'      '82.6'
# 3924    '29.668'    '29.571'      '19.6'      '24.2'      '79.7'
# 3925    '29.686'    '29.577'      '15.0'      '25.3'      '77.4'
# 3926    '29.781'    '29.645'       '8.1'      '17.3'      '77.5'
# 3927     '29.93'    '29.745'      '11.5'      '15.0'      '77.5'
# 3928    '29.941'    '29.781'      '13.8'      '18.4'      '78.2'
# 3929    '29.792'    '29.675'      '17.3'      '26.5'      '77.6'
# 3930    '29.792'    '29.675'      '17.3'      '26.5'      '77.6'
#
#        Unnamed: 20 Unnamed: 21             Unnamed: 22
# 3921  '2022-07-20'        '07'   '0.14499999999999957'
# 3922  '2022-07-21'        '07'   '0.14199999999999946'
# 3923  '2022-07-22'        '07'   '0.12400000000000233'
# 3924  '2022-07-23'        '07'   '0.09699999999999775'
# 3925  '2022-07-24'        '07'   '0.10899999999999821'
# 3926  '2022-07-25'        '07'   '0.13599999999999923'
# 3927  '2022-07-26'        '07'   '0.18499999999999872'
# 3928  '2022-07-27'        '07'   '0.16000000000000014'
# 3929  '2022-07-28'        '07'  '0.11700000000000088';
# 3930  '2022-07-28'        '07'  '0.11700000000000088';
#
# [10 rows x 23 columns]
